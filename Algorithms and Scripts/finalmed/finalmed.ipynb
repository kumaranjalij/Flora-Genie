# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/kmeans-cosine/KMeans_cluster_means_df.csv
# /kaggle/input/kmeans-cosine/data_indiaplant_1_3000.csv
# /kaggle/input/kmeans-cosine/KMeans_data_with_cluster_id.csv
# /kaggle/input/meddata/final_data_encoded_Med.csv
# /kaggle/input/meddata/Complete_Medicinal_Data.csv

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
data_cosine=pd.read_csv("/kaggle/input/meddata/final_data_encoded_Med.csv", index_col=0)

# %%
data_cosine
# Out:
#           Category_Annuals  Category_Aquatic Plants  \
# Plant_Id
# 41                       0                        0
# 42                       0                        0
# 43                       0                        0
# 137                      0                        0
# 143                      0                        0
# ...                    ...                      ...
# 4727                     0                        0
# 4728                     0                        0
# 4729                     0                        0
# 4730                     0                        0
# 4731                     0                        0
#
#           Category_Aquatic and Marginal Plants  Category_Bamboos  \
# Plant_Id
# 41                                           0                 0
# 42                                           0                 0
# 43                                           0                 0
# 137                                          0                 0
# 143                                          0                 0
# ...                                        ...               ...
# 4727                                         0                 0
# 4728                                         0                 0
# 4729                                         0                 0
# 4730                                         0                 0
# 4731                                         0                 0
#
#           Category_Bromeliads  Category_Bulbous Plants  Category_Bulbs  \
# Plant_Id
# 41                          0                        0               0
# 42                          0                        0               0
# 43                          0                        0               0
# 137                         0                        0               0
# 143                         0                        0               0
# ...                       ...                      ...             ...
# 4727                        0                        0               0
# 4728                        0                        0               0
# 4729                        0                        0               0
# 4730                        0                        0               0
# 4731                        0                        0               0
#
#           Category_Cacti & Succulents  Category_Climbers  \
# Plant_Id
# 41                                  0                  0
# 42                                  0                  0
# 43                                  0                  1
# 137                                 0                  0
# 143                                 0                  0
# ...                               ...                ...
# 4727                                0                  0
# 4728                                0                  0
# 4729                                0                  0
# 4730                                0                  0
# 4731                                0                  0
#
#           Category_Climbers and Creepers  ...  Diseases_systemic  \
# Plant_Id                                  ...
# 41                                     0  ...                  0
# 42                                     0  ...                  0
# 43                                     0  ...                  0
# 137                                    0  ...                  0
# 143                                    0  ...                  0
# ...                                  ...  ...                ...
# 4727                                   0  ...                  0
# 4728                                   0  ...                  0
# 4729                                   0  ...                  0
# 4730                                   0  ...                  0
# 4731                                   0  ...                  0
#
#           Diseases_ulcerative  Diseases_variant  Diseases_viral  \
# Plant_Id
# 41                          0                 0               0
# 42                          0                 0               0
# 43                          0                 0               0
# 137                         0                 0               0
# 143                         0                 0               0
# ...                       ...               ...             ...
# 4727                        0                 0               0
# 4728                        0                 0               0
# 4729                        0                 0               0
# 4730                        0                 0               0
# 4731                        0                 0               0
#
#           Diseases_visceral  Diseases_vulvovaginal  Diseases_walker  \
# Plant_Id
# 41                        0                      0                0
# 42                        0                      0                0
# 43                        0                      0                0
# 137                       0                      0                0
# 143                       0                      0                0
# ...                     ...                    ...              ...
# 4727                      0                      0                0
# 4728                      0                      0                0
# 4729                      0                      0                0
# 4730                      0                      0                0
# 4731                      0                      0                0
#
#           Category_Rose_Hybrid_Climbers  Category_Rose_Miniature_Floribundas  \
# Plant_Id
# 41                                    0                                    0
# 42                                    0                                    0
# 43                                    0                                    0
# 137                                   0                                    0
# 143                                   0                                    0
# ...                                 ...                                  ...
# 4727                                  0                                    0
# 4728                                  0                                    0
# 4729                                  0                                    0
# 4730                                  0                                    0
# 4731                                  0                                    0
#
#           Category_Groundcovers_lawns
# Plant_Id
# 41                                  0
# 42                                  1
# 43                                  1
# 137                                 1
# 143                                 0
# ...                               ...
# 4727                                0
# 4728                                0
# 4729                                0
# 4730                                0
# 4731                                0
#
# [958 rows x 836 columns]

# %%
# Load in the data and scale it
plant_data = pd.read_csv('/kaggle/input/meddata/Complete_Medicinal_Data.csv', sep=";", index_col=0)

# %%
# for med
plant_data
# Out:
#                                      Scientific_Name  \
# Plant_Id
# 41                                   Garcinia indica
# 42                                 Centella asiatica
# 43                                 Abrus precatorius
# 137                                   Tagetes patula
# 143       Anacardium occidentale, Acajou occidentale
# ...                                              ...
# 4727                              Commiphora caudata
# 4728                               Commiphora myrrha
# 4729                           Commiphora stocksiana
# 4730                              Commiphora wightii
# 4731                             Connarus monocarpus
#
#                                          Common_Name  \
# Plant_Id
# 41                        Red Mango Tree, Raktapurka
# 42          Brahmi Big Leaved, Brahma-manduki, Brahm
# 43        Indian Licorice, Chanoti, Deadly Crabs Eye
# 137                                  Marigold French
# 143                   Cashew Nut, Kaju, Cashew Apple
# ...                                              ...
# 4727                                  Balasmodendron
# 4728                                      Myrrh Tree
# 4729                                    Indian Myrrh
# 4730                                    Indian Myrrh
# 4731                                Fish Poison Tree
#
#                                               Regional_Name  \
# Plant_Id
# 41        Hindi – Kokum, Marathi - Bheranda, Kokamba, Ko...
# 42        Hindi - Brahma-manduki, Bengali - Potari, Guja...
# 43        Marathi - Gunja, Assamese - Liluwani, Bengali ...
# 137       Marathi - Zendu, Hindi - Genda, Bengali - Gend...
# 143       Marathi - Kaju, Hindi - Kaju, Bengali - Hijiba...
# ...                                                     ...
# 4727                                         Balasmodendron
# 4728                                             Myrrh Tree
# 4729                                           Indian Myrrh
# 4730                                           Indian Myrrh
# 4731                                       Fish Poison Tree
#
#                                                    Category  \
# Plant_Id
# 41                          Trees, Medicinal Plants, Shrubs
# 42                           Medicinal Plants, Groundcovers
# 43        Medicinal Plants, Climbers, Creepers & Vines, ...
# 137                      Flowering Pot Plants, Groundcovers
# 143                   Fruit Plants, Trees, Medicinal Plants
# ...                                                     ...
# 4727                                       Medicinal Plants
# 4728                                       Medicinal Plants
# 4729                                       Medicinal Plants
# 4730                                       Medicinal Plants
# 4731                                       Medicinal Plants
#
#                                            Family                    Light  \
# Plant_Id
# 41                    Guttiferae or Nutmeg family  Sun growing, Semi shade
# 42                      Apiaceae or Carrot family  Sun growing, Semi shade
# 43          Leguminosae or Fabaceae or Pea family  Sun growing, Semi shade
# 137                Compositae or Sunflower family  Sun growing, Semi shade
# 143       Anacardiaceae or Mango or Cashew family  Sun growing, Semi shade
# ...                                           ...                      ...
# 4727                                  Burseraceae              Sun growing
# 4728                                  Burseraceae              Sun growing
# 4729                                  Burseraceae              Sun growing
# 4730                                  Burseraceae              Sun growing
# 4731                                  Connaraceae              Sun growing
#
#                                                  Water Primary_Grown_for  \
# Plant_Id
# 41                           Normal, Can tolerate more     Fruit or Seed
# 42                                              Normal           Foliage
# 43        Normal, Can tolerate less, Can tolerate more           Foliage
# 137                                             Normal           Flowers
# 143       Normal, Can tolerate less, Can tolerate more     Fruit or Seed
# ...                                                ...               ...
# 4727                                     Requires more   Stems or Timber
# 4728                                     Requires more   Stems or Timber
# 4729                                     Requires more   Stems or Timber
# 4730                                     Requires more   Stems or Timber
# 4731                                     Requires more   Stems or Timber
#
#                                            Flowering_Season Foliage_Color  \
# Plant_Id
# 41        January, February, November, December, Flowers...   Green, Pink
# 42        May, June, July, August, September, October, N...         Green
# 43                                     March, April, August         Green
# 137                                   Year-around flowering         Green
# 143       January, February, November, December, Flowers...    Green, Red
# ...                                                     ...           ...
# 4727                                  Year-around flowering         Green
# 4728                                  Year-around flowering         Green
# 4729                                  Year-around flowering         Green
# 4730                                  Year-around flowering         Green
# 4731                                  Year-around flowering         Green
#
#           ... Med_Plant_Id   Med_Plant_Name_Mapped  \
# Plant_Id  ...
# 41        ...         5467         Garcinia indica
# 42        ...         2394       Centella asiatica
# 43        ...           18       Abrus precatorius
# 137       ...        12030          Tagetes erecta
# 143       ...          606  Anacardium occidentale
# ...       ...          ...                     ...
# 4727      ...         2997      Commiphora caudata
# 4728      ...         3000       Commiphora myrrha
# 4729      ...         3001   Commiphora stocksiana
# 4730      ...         3002      Commiphora wightii
# 4731      ...         3012     Connarus monocarpus
#
#                                               Med_Plant_Use Med_Kingdom  \
# Plant_Id
# 41        [['fruit', 'Anti-bacterial agents'], ['None', ...     Plantae
# 42        [['None', 'Dysentery'], ['None', 'Emaciation']...     Plantae
# 43        [['seed', 'Hemagglutination'], ['root', 'Stoma...     Plantae
# 137       [['leaf', 'Antinematodal agents'], ['whole pla...     Plantae
# 143       [['fruit', 'Hair loss'], ['bark', 'Callosities...     Plantae
# ...                                                     ...         ...
# 4727      [['leaf', 'Fissure'], ['leaf', 'Arthritis'], [...     Plantae
# 4728      [['None', 'Urologic diseases'], ['None', 'Gene...     Plantae
# 4729      [['plant exudate', 'Ulcer'], ['plant exudate',...     Plantae
# 4730      [['plant exudate', 'Snake bites'], ['plant exu...     Plantae
# 4731      [['wood', 'Ulcer'], ['wood', 'Furunculosis'], ...     Plantae
#
#              Med_Family    Med_Group          Med_Common_Name  \
# Plant_Id
# 41           Clusiaceae  Angiosperms                    Kokam
# 42             Apiaceae  Angiosperms         Indian Pennywort
# 43          Leguminosae  Angiosperms               Rosary Pea
# 137          Compositae  Angiosperms                 Marigold
# 143       Anacardiaceae  Angiosperms                   Cashew
# ...                 ...          ...                      ...
# 4727        Burseraceae  Angiosperms  South-Indian Commiphora
# 4728        Burseraceae  Angiosperms                      NaN
# 4729        Burseraceae  Angiosperms                      NaN
# 4730        Burseraceae  Angiosperms                   Guggal
# 4731        Connaraceae  Angiosperms                      NaN
#
#                                        Med_Synonymous_names  \
# Plant_Id
# 41                       Garcinia indica, Garcinia purpurea
# 42        Hydrocotyle asiatica, Centella asiatica, Cante...
# 43        Abrus precatorius, Abrus precatorious, Abies p...
# 137       Tagetes patula, Tagetes erecta, Tagetes ereta,...
# 143          Anacardium occidentale, Anacardium occidantale
# ...                                                     ...
# 4727             Balsamodendron caudata, Commiphora caudata
# 4728               Balsamodendron myrrha, Commiphora myrrha
# 4729        Balsamodendron pubescens, Commiphora stocksiana
# 4730              Commiphora wightii, Commiphora roxburghii
# 4731                                    Connarus monocarpus
#
#                                    Med_System_of_medicine Curated
# Plant_Id
# 41                           Ayurveda, Siddha, Sowa Rigpa       0
# 42        Ayurveda, Homeopathy, Siddha, Sowa Rigpa, Unani       0
# 43        Ayurveda, Homeopathy, Siddha, Sowa Rigpa, Unani       0
# 137                               Ayurveda, Siddha, Unani       0
# 143                   Ayurveda, Homeopathy, Siddha, Unani       0
# ...                                                   ...     ...
# 4727                                     Ayurveda, Siddha       1
# 4728                  Ayurveda, Siddha, Sowa Rigpa, Unani       1
# 4729                                             Ayurveda       1
# 4730                  Ayurveda, Siddha, Sowa Rigpa, Unani       1
# 4731                                               Siddha       1
#
# [958 rows x 27 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_plants_cosine(input_values, data, top_n=20):
    # Filter data based on input values
    filtered_data = data.copy()
    for column, value in input_values.items():
        if column in filtered_data.columns:
            filtered_data = filtered_data[filtered_data[column] == value]

    if len(filtered_data) == 0:
        print("No matching plants found for the input criteria.")
        return None
    
    # Prepare input vector for cosine similarity
    input_vector = pd.DataFrame(index=[0], columns=data.columns)
    input_vector = input_vector.fillna(0)  # Fill with zeros initially
    for column, value in input_values.items():
        if column in input_vector.columns:
            input_vector.at[0, column] = 1  # Set the input value to 1 in the input vector

    # Calculate cosine similarity between input vector and filtered data
    similarity_scores = cosine_similarity(input_vector.values, filtered_data.values)
    # Add similarity scores to the filtered data
    filtered_data['Similarity'] = similarity_scores.flatten()

    # Sort by similarity scores in descending order
    recommended_plants = filtered_data.sort_values(by='Similarity', ascending=False).head(top_n)
    #print(recommended_plants)
    return recommended_plants[['Similarity']]

# %%
# Example usage:
input_values = {
    
    'Diseases_Fever': 1,
    'Diseases_Cough': 1,
}

recommendations = recommend_plants_cosine(input_values,data_cosine)
if recommendations is not None:
    print(recommendations)
# Out:
#           Similarity
# Plant_Id
# 4650        0.471405
# 4036        0.426401
# 4554        0.408248
# 4553        0.408248
# 4271        0.408248
# 4307        0.392232
# 4445        0.353553
# 1916        0.342997
# 4117        0.333333
# 4175        0.333333
# 4236        0.333333
# 4708        0.333333
# 4692        0.316228
# 4306        0.308607
# 467         0.308607
# 4361        0.301511
# 4483        0.301511
# 4484        0.301511
# 4355        0.294884
# 4693        0.288675
# /tmp/ipykernel_33/3373127197.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   input_vector = input_vector.fillna(0)  # Fill with zeros initially

# %%
list_plant = recommendations.index.tolist()
list_plant
# Out:
# [4650,
#  4036,
#  4554,
#  4553,
#  4271,
#  4307,
#  4445,
#  1916,
#  4117,
#  4175,
#  4236,
#  4708,
#  4692,
#  4306,
#  467,
#  4361,
#  4483,
#  4484,
#  4355,
#  4693]

# %%
plant_data.columns
# Out:
# Index(['Scientific_Name', 'Common_Name', 'Regional_Name', 'Category', 'Family',
#        'Light', 'Water', 'Primary_Grown_for', 'Flowering_Season',
#        'Foliage_Color', 'Height_or_Length', 'Spread_or_Width', 'Plant_Form',
#        'Lifespan', 'Special_Feature', 'Plant_Description', 'Growing_Tips',
#        'Med_Plant_Id', 'Med_Plant_Name_Mapped', 'Med_Plant_Use', 'Med_Kingdom',
#        'Med_Family', 'Med_Group', 'Med_Common_Name', 'Med_Synonymous_names',
#        'Med_System_of_medicine', 'Curated'],
#       dtype='object')

# %%
extracted_rows = plant_data.loc[list_plant]

# %%
extracted_rows.head(20)
# Out:
#                       Scientific_Name  \
# Plant_Id
# 4650         Cinnamomum glanduliferum
# 4036          Acanthospermum hispidum
# 4554             Canthium parviflorum
# 4553          Canthium coromandelicum
# 4271               Bischofia javanica
# 4307              Bridelia stipularis
# 4445                  Croton caudatus
# 1916                      Alcea rosea
# 4117                Anisomeles indica
# 4175              Artemisia myriantha
# 4236            Barringtonia racemosa
# 4708            Codariocalyx motorius
# 4692      Clerodendrum colebrookianum
# 4306                  Bridelia retusa
# 467                  Bambusa vulgaris
# 4361               Corchorus aestuans
# 4483                  Cydonia oblonga
# 4484                 Cydonia vulgaris
# 4355           Convolvulus prostratus
# 4693             Clerodendrum indicum
#
#                                                 Common_Name  \
# Plant_Id
# 4650                                        Indian Cinnamon
# 4036                                        Hispid Starburr
# 4554                                                    NaN
# 4553                                                    NaN
# 4271                                                    NaN
# 4307                                                    NaN
# 4445                                                    NaN
# 1916                                              Hollyhock
# 4117                                                    NaN
# 4175                                                    NaN
# 4236                                                    NaN
# 4708                                          Dancing Plant
# 4692                                           Snake Tongue
# 4306                                                    NaN
# 467       Bamboo Golden Variegated, Feathery Bamboo, Tig...
# 4361                                           Chinese jute
# 4483                                                    NaN
# 4484                                                    NaN
# 4355                                     Prostrate bindweed
# 4693                                          Turk's Turban
#
#                                               Regional_Name  \
# Plant_Id
# 4650                                        Indian Cinnamon
# 4036                                                  India
# 4554                                                    NaN
# 4553                                                    NaN
# 4271                                                    NaN
# 4307                                                    NaN
# 4445                                                    NaN
# 1916                                                    NaN
# 4117                                                  India
# 4175                                                  India
# 4236                                                  India
# 4708                                          Dancing Plant
# 4692                                           Snake Tongue
# 4306                                                    NaN
# 467       Marathi - Kalaka, Hindi - Udha-bans, Bengali -...
# 4361                                                    NaN
# 4483                                                    NaN
# 4484                                                    NaN
# 4355                                                    NaN
# 4693                                             Tight Head
#
#                                                    Category  \
# Plant_Id
# 4650                            Spice plants & edible Herbs
# 4036                                                  Herbs
# 4554                                                  Trees
# 4553                                                  Trees
# 4271                                                  Trees
# 4307                                                 Shrubs
# 4445                                                 Shrubs
# 1916                                                 Shrubs
# 4117                                                  Herbs
# 4175                                                  Herbs
# 4236                                                  Trees
# 4708                                   Flowering Pot Plants
# 4692                                   Flowering Pot Plants
# 4306                                                 Shrubs
# 467       Bamboos, Grasses & Grass like plants, Medicina...
# 4361                                              Vegetable
# 4483                                           Fruit Plants
# 4484                                           Fruit Plants
# 4355                                       Creepers & Vines
# 4693                                   Flowering Pot Plants
#
#                                        Family                    Light  \
# Plant_Id
# 4650                                Lauraceae              Sun growing
# 4036                               Asteraceae              Sun growing
# 4554                                      NaN              Sun growing
# 4553                                      NaN            Shade growing
# 4271                                      NaN              Sun growing
# 4307                                      NaN       Low light tolerant
# 4445                            Euphorbiaceae              Sun growing
# 1916      Malvaceae Hibiscus or Cotton family              Sun growing
# 4117                                Lamiaceae              Sun growing
# 4175                               Asteraceae              Sun growing
# 4236                            Lecythidaceae              Sun growing
# 4708                                 Fabaceae              Sun growing
# 4692                              Verbenaceae              Sun growing
# 4306                                      NaN              Sun growing
# 467                    Moraceae or Fig family  Sun growing, Semi shade
# 4361                                Malvaceae              Sun growing
# 4483                                 Rosaceae              Sun growing
# 4484                                 Rosaceae              Sun growing
# 4355                           Convolvulaceae              Sun growing
# 4693                              Verbenaceae              Sun growing
#
#                               Water Primary_Grown_for  \
# Plant_Id
# 4650                  Requires more      Bark or Wood
# 4036                Requires normal   Roots or tubers
# 4554              Can tolerate less           Foliage
# 4553                  Requires less           Foliage
# 4271                  Requires more   Stems or Timber
# 4307              Can tolerate more           Flowers
# 4445                  Requires more           Foliage
# 1916                         Normal           Flowers
# 4117                Requires normal           Foliage
# 4175                Requires normal           Foliage
# 4236                Requires normal     Fruit or Seed
# 4708                  Requires more            Leaves
# 4692                  Requires more   Stems or Timber
# 4306                  Requires less           Flowers
# 467       Normal, Can tolerate more           Foliage
# 4361                  Requires more           Foliage
# 4483                  Requires more     Fruit or Seed
# 4484                  Requires more     Fruit or Seed
# 4355                  Requires more           Foliage
# 4693                  Requires more   Stems or Timber
#
#                                            Flowering_Season  Foliage_Color  \
# Plant_Id
# 4650                 Flowers in flushes throughout the year          Green
# 4036                                  Year-around flowering          Green
# 4554                                  Year-around flowering          Green
# 4553                                  Year-around flowering          Green
# 4271                                  Year-around flowering          Green
# 4307                                  Year-around flowering          White
# 4445                                  Year-around flowering          Green
# 1916                                  Year-around flowering          Green
# 4117                                  Year-around flowering          Green
# 4175                                  Year-around flowering          Green
# 4236                                  Year-around flowering          Green
# 4708                                  Year-around flowering          Green
# 4692                                  Year-around flowering          Green
# 4306                                  Year-around flowering          White
# 467       Flowers once in many years, Flowers are incons...  Green, Yellow
# 4361                                  Year-around flowering          Green
# 4483                                  Year-around flowering          Green
# 4484                                  Year-around flowering          Green
# 4355                                  Year-around flowering          Green
# 4693                                  Year-around flowering          Green
#
#           ... Med_Plant_Id     Med_Plant_Name_Mapped  \
# Plant_Id  ...
# 4650      ...         2674  Cinnamomum glanduliferum
# 4036      ...          127   Acanthospermum hispidum
# 4554      ...         2078   Canthium coromandelicum
# 4553      ...         2073   Canthium coromandelicum
# 4271      ...         1511        Bischofia javanica
# 4307      ...         1714       Bridelia stipularis
# 4445      ...         3329           Croton caudatus
# 1916      ...          382               Alcea rosea
# 4117      ...          743         Anisomeles indica
# 4175      ...         1048       Artemisia myriantha
# 4236      ...         1352     Barringtonia racemosa
# 4708      ...         2897     Codariocalyx motorius
# 4692      ...         2843  Clerodendrum glandulosum
# 4306      ...         1713           Bridelia retusa
# 467       ...         1311          Bambusa vulgaris
# 4361      ...         3038        Corchorus aestuans
# 4483      ...         3491           Cydonia oblonga
# 4484      ...         3492           Cydonia oblonga
# 4355      ...         3021    Convolvulus prostratus
# 4693      ...         2848      Clerodendrum indicum
#
#                                               Med_Plant_Use Med_Kingdom  \
# Plant_Id
# 4650      [['bark', 'Fever'], ['leaf', 'Fever'], ['bark'...     Plantae
# 4036      [['leaf', 'Fever'], ['fruit', 'Cough'], ['frui...     Plantae
# 4554      [['None', 'Asthenia'], ['None', 'Diuretics'], ...     Plantae
# 4553      [['None', 'Asthenia'], ['None', 'Diuretics'], ...     Plantae
# 4271      [['bark', 'Fever'], ['bark', 'Burns'], ['leaf'...     Plantae
# 4307      [['bark', 'Fever'], ['leaf', 'Wounds and injur...     Plantae
# 4445      [['leaf', 'Pain'], ['stem', 'Wounds and injuri...     Plantae
# 1916      [['flower', 'Cathartics'], ['seed', 'Diuretics...     Plantae
# 4117      [['None', 'General tonic for rejuvenation'], [...     Plantae
# 4175      [['leaf', 'Pain'], ['leaf', 'Pruritus'], ['lea...     Plantae
# 4236      [['bark', 'Insecticides'], ['seed', 'Endophtha...     Plantae
# 4708      [['root', 'Fever'], ['root', 'Liver diseases']...     Plantae
# 4692      [['leaf', 'Hypolipidemic agents'], ['leaf', 'H...     Plantae
# 4306      [['bark', 'Astringents'], ['bark', 'Earache'],...     Plantae
# 467       [['whole plant excluding root', 'Contraceptive...     Plantae
# 4361      [['aerial part', 'Anti-inflammatory agents'], ...     Plantae
# 4483      [['plant exudate', 'Burns'], ['plant exudate',...     Plantae
# 4484      [['plant exudate', 'Burns'], ['plant exudate',...     Plantae
# 4355      [['whole plant', 'Diabetes mellitus'], ['None'...     Plantae
# 4693      [['root', 'Intestinal diseases, parasitic'], [...     Plantae
#
#               Med_Family    Med_Group      Med_Common_Name  \
# Plant_Id
# 4650           Lauraceae  Angiosperms                  NaN
# 4036          Compositae  Angiosperms      Bristly Starbur
# 4554           Rubiaceae  Angiosperms   Coromandel Boxwood
# 4553           Rubiaceae  Angiosperms   Coromandel Boxwood
# 4271      Phyllanthaceae  Angiosperms          Bishop Wood
# 4307      Phyllanthaceae  Angiosperms    Climbing Bridelia
# 4445       Euphorbiaceae  Angiosperms      Climbing Croton
# 1916           Malvaceae  Angiosperms            Hollyhock
# 4117           Lamiaceae  Angiosperms       Indian Catmint
# 4175          Compositae  Angiosperms                  NaN
# 4236       Lecythidaceae  Angiosperms  Powderpuff Mangrove
# 4708         Leguminosae  Angiosperms      Telegraph Plant
# 4692           Lamiaceae  Angiosperms                  NaN
# 4306      Phyllanthaceae  Angiosperms    Spinous Kino Tree
# 467              Poaceae  Angiosperms        Golden Bamboo
# 4361           Malvaceae  Angiosperms   East Indian Mallow
# 4483            Rosaceae  Angiosperms               Quince
# 4484            Rosaceae  Angiosperms               Quince
# 4355      Convolvulaceae  Angiosperms        Shankh Pushpi
# 4693           Lamiaceae  Angiosperms           Tubeflower
#
#                                        Med_Synonymous_names  \
# Plant_Id
# 4650                               Cinnamomum glanduliferum
# 4036                                Acanthospermum hispidum
# 4554      Canthium parviflorum, Canthium coromandelicum,...
# 4553      Canthium parviflorum, Canthium coromandelicum,...
# 4271                                     Bischofia javanica
# 4307      Bridelia stipularis, Bridelia scandens, Bridel...
# 4445                                        Croton caudatus
# 1916                             Althaea rosea, Alcea rosea
# 4117      Anisomeles ovata, Anisomeles indica, Anisomele...
# 4175                                    Artemisia myriantha
# 4236           Barringtonia racemosa, Barringionia racemosa
# 4708      Desmodium gyrans, Desmodium motorium, Codarioc...
# 4692      Clerodendrum colebrookianum, Clerodendrum glan...
# 4306      Bridelia airy-shawii, Bridelia squamosa, Bride...
# 467                                        Bambusa vulgaris
# 4361      Corchorus acutangularis, Corchorus acutangulus...
# 4483       Cydonia vulgaris, Cydonia oblonga, Pyrus cydonia
# 4484       Cydonia vulgaris, Cydonia oblonga, Pyrus cydonia
# 4355      Convolvulus pluricaulis, Convolvulus prostratu...
# 4693        Clerodendrum siphonanthus, Clerodendrum indicum
#
#            Med_System_of_medicine Curated
# Plant_Id
# 4650                          NaN       1
# 4036                     Ayurveda       1
# 4554             Ayurveda, Siddha       1
# 4553             Ayurveda, Siddha       1
# 4271                       Siddha       1
# 4307                     Ayurveda       1
# 4445                          NaN       1
# 1916                          NaN       0
# 4117                       Siddha       1
# 4175                          NaN       1
# 4236             Ayurveda, Siddha       1
# 4708                          NaN       1
# 4692                          NaN       1
# 4306             Ayurveda, Siddha       1
# 467                           NaN       0
# 4361              Ayurveda, Unani       1
# 4483      Ayurveda, Siddha, Unani       1
# 4484      Ayurveda, Siddha, Unani       1
# 4355      Ayurveda, Siddha, Unani       1
# 4693             Ayurveda, Siddha       1
#
# [20 rows x 27 columns]

# %%
df=extracted_rows

# %%
# Assuming your dataset is in a pandas DataFrame called 'df'

# Separate rows where 'Curated' equals 0 and where it doesn't
curated_zero = df[df['Curated'] == 0]
curated_non_zero = df[df['Curated'] != 0]

# Concatenate the two separated dataframes
df_reordered = pd.concat([curated_zero, curated_non_zero])

# Now df_reordered contains rows where 'Curated' equals 0 followed by rows where it doesn't

# %%
df_reordered
# Out:
#                       Scientific_Name  \
# Plant_Id
# 1916                      Alcea rosea
# 467                  Bambusa vulgaris
# 4650         Cinnamomum glanduliferum
# 4036          Acanthospermum hispidum
# 4554             Canthium parviflorum
# 4553          Canthium coromandelicum
# 4271               Bischofia javanica
# 4307              Bridelia stipularis
# 4445                  Croton caudatus
# 4117                Anisomeles indica
# 4175              Artemisia myriantha
# 4236            Barringtonia racemosa
# 4708            Codariocalyx motorius
# 4692      Clerodendrum colebrookianum
# 4306                  Bridelia retusa
# 4361               Corchorus aestuans
# 4483                  Cydonia oblonga
# 4484                 Cydonia vulgaris
# 4355           Convolvulus prostratus
# 4693             Clerodendrum indicum
#
#                                                 Common_Name  \
# Plant_Id
# 1916                                              Hollyhock
# 467       Bamboo Golden Variegated, Feathery Bamboo, Tig...
# 4650                                        Indian Cinnamon
# 4036                                        Hispid Starburr
# 4554                                                    NaN
# 4553                                                    NaN
# 4271                                                    NaN
# 4307                                                    NaN
# 4445                                                    NaN
# 4117                                                    NaN
# 4175                                                    NaN
# 4236                                                    NaN
# 4708                                          Dancing Plant
# 4692                                           Snake Tongue
# 4306                                                    NaN
# 4361                                           Chinese jute
# 4483                                                    NaN
# 4484                                                    NaN
# 4355                                     Prostrate bindweed
# 4693                                          Turk's Turban
#
#                                               Regional_Name  \
# Plant_Id
# 1916                                                    NaN
# 467       Marathi - Kalaka, Hindi - Udha-bans, Bengali -...
# 4650                                        Indian Cinnamon
# 4036                                                  India
# 4554                                                    NaN
# 4553                                                    NaN
# 4271                                                    NaN
# 4307                                                    NaN
# 4445                                                    NaN
# 4117                                                  India
# 4175                                                  India
# 4236                                                  India
# 4708                                          Dancing Plant
# 4692                                           Snake Tongue
# 4306                                                    NaN
# 4361                                                    NaN
# 4483                                                    NaN
# 4484                                                    NaN
# 4355                                                    NaN
# 4693                                             Tight Head
#
#                                                    Category  \
# Plant_Id
# 1916                                                 Shrubs
# 467       Bamboos, Grasses & Grass like plants, Medicina...
# 4650                            Spice plants & edible Herbs
# 4036                                                  Herbs
# 4554                                                  Trees
# 4553                                                  Trees
# 4271                                                  Trees
# 4307                                                 Shrubs
# 4445                                                 Shrubs
# 4117                                                  Herbs
# 4175                                                  Herbs
# 4236                                                  Trees
# 4708                                   Flowering Pot Plants
# 4692                                   Flowering Pot Plants
# 4306                                                 Shrubs
# 4361                                              Vegetable
# 4483                                           Fruit Plants
# 4484                                           Fruit Plants
# 4355                                       Creepers & Vines
# 4693                                   Flowering Pot Plants
#
#                                        Family                    Light  \
# Plant_Id
# 1916      Malvaceae Hibiscus or Cotton family              Sun growing
# 467                    Moraceae or Fig family  Sun growing, Semi shade
# 4650                                Lauraceae              Sun growing
# 4036                               Asteraceae              Sun growing
# 4554                                      NaN              Sun growing
# 4553                                      NaN            Shade growing
# 4271                                      NaN              Sun growing
# 4307                                      NaN       Low light tolerant
# 4445                            Euphorbiaceae              Sun growing
# 4117                                Lamiaceae              Sun growing
# 4175                               Asteraceae              Sun growing
# 4236                            Lecythidaceae              Sun growing
# 4708                                 Fabaceae              Sun growing
# 4692                              Verbenaceae              Sun growing
# 4306                                      NaN              Sun growing
# 4361                                Malvaceae              Sun growing
# 4483                                 Rosaceae              Sun growing
# 4484                                 Rosaceae              Sun growing
# 4355                           Convolvulaceae              Sun growing
# 4693                              Verbenaceae              Sun growing
#
#                               Water Primary_Grown_for  \
# Plant_Id
# 1916                         Normal           Flowers
# 467       Normal, Can tolerate more           Foliage
# 4650                  Requires more      Bark or Wood
# 4036                Requires normal   Roots or tubers
# 4554              Can tolerate less           Foliage
# 4553                  Requires less           Foliage
# 4271                  Requires more   Stems or Timber
# 4307              Can tolerate more           Flowers
# 4445                  Requires more           Foliage
# 4117                Requires normal           Foliage
# 4175                Requires normal           Foliage
# 4236                Requires normal     Fruit or Seed
# 4708                  Requires more            Leaves
# 4692                  Requires more   Stems or Timber
# 4306                  Requires less           Flowers
# 4361                  Requires more           Foliage
# 4483                  Requires more     Fruit or Seed
# 4484                  Requires more     Fruit or Seed
# 4355                  Requires more           Foliage
# 4693                  Requires more   Stems or Timber
#
#                                            Flowering_Season  Foliage_Color  \
# Plant_Id
# 1916                                  Year-around flowering          Green
# 467       Flowers once in many years, Flowers are incons...  Green, Yellow
# 4650                 Flowers in flushes throughout the year          Green
# 4036                                  Year-around flowering          Green
# 4554                                  Year-around flowering          Green
# 4553                                  Year-around flowering          Green
# 4271                                  Year-around flowering          Green
# 4307                                  Year-around flowering          White
# 4445                                  Year-around flowering          Green
# 4117                                  Year-around flowering          Green
# 4175                                  Year-around flowering          Green
# 4236                                  Year-around flowering          Green
# 4708                                  Year-around flowering          Green
# 4692                                  Year-around flowering          Green
# 4306                                  Year-around flowering          White
# 4361                                  Year-around flowering          Green
# 4483                                  Year-around flowering          Green
# 4484                                  Year-around flowering          Green
# 4355                                  Year-around flowering          Green
# 4693                                  Year-around flowering          Green
#
#           ... Med_Plant_Id     Med_Plant_Name_Mapped  \
# Plant_Id  ...
# 1916      ...          382               Alcea rosea
# 467       ...         1311          Bambusa vulgaris
# 4650      ...         2674  Cinnamomum glanduliferum
# 4036      ...          127   Acanthospermum hispidum
# 4554      ...         2078   Canthium coromandelicum
# 4553      ...         2073   Canthium coromandelicum
# 4271      ...         1511        Bischofia javanica
# 4307      ...         1714       Bridelia stipularis
# 4445      ...         3329           Croton caudatus
# 4117      ...          743         Anisomeles indica
# 4175      ...         1048       Artemisia myriantha
# 4236      ...         1352     Barringtonia racemosa
# 4708      ...         2897     Codariocalyx motorius
# 4692      ...         2843  Clerodendrum glandulosum
# 4306      ...         1713           Bridelia retusa
# 4361      ...         3038        Corchorus aestuans
# 4483      ...         3491           Cydonia oblonga
# 4484      ...         3492           Cydonia oblonga
# 4355      ...         3021    Convolvulus prostratus
# 4693      ...         2848      Clerodendrum indicum
#
#                                               Med_Plant_Use Med_Kingdom  \
# Plant_Id
# 1916      [['flower', 'Cathartics'], ['seed', 'Diuretics...     Plantae
# 467       [['whole plant excluding root', 'Contraceptive...     Plantae
# 4650      [['bark', 'Fever'], ['leaf', 'Fever'], ['bark'...     Plantae
# 4036      [['leaf', 'Fever'], ['fruit', 'Cough'], ['frui...     Plantae
# 4554      [['None', 'Asthenia'], ['None', 'Diuretics'], ...     Plantae
# 4553      [['None', 'Asthenia'], ['None', 'Diuretics'], ...     Plantae
# 4271      [['bark', 'Fever'], ['bark', 'Burns'], ['leaf'...     Plantae
# 4307      [['bark', 'Fever'], ['leaf', 'Wounds and injur...     Plantae
# 4445      [['leaf', 'Pain'], ['stem', 'Wounds and injuri...     Plantae
# 4117      [['None', 'General tonic for rejuvenation'], [...     Plantae
# 4175      [['leaf', 'Pain'], ['leaf', 'Pruritus'], ['lea...     Plantae
# 4236      [['bark', 'Insecticides'], ['seed', 'Endophtha...     Plantae
# 4708      [['root', 'Fever'], ['root', 'Liver diseases']...     Plantae
# 4692      [['leaf', 'Hypolipidemic agents'], ['leaf', 'H...     Plantae
# 4306      [['bark', 'Astringents'], ['bark', 'Earache'],...     Plantae
# 4361      [['aerial part', 'Anti-inflammatory agents'], ...     Plantae
# 4483      [['plant exudate', 'Burns'], ['plant exudate',...     Plantae
# 4484      [['plant exudate', 'Burns'], ['plant exudate',...     Plantae
# 4355      [['whole plant', 'Diabetes mellitus'], ['None'...     Plantae
# 4693      [['root', 'Intestinal diseases, parasitic'], [...     Plantae
#
#               Med_Family    Med_Group      Med_Common_Name  \
# Plant_Id
# 1916           Malvaceae  Angiosperms            Hollyhock
# 467              Poaceae  Angiosperms        Golden Bamboo
# 4650           Lauraceae  Angiosperms                  NaN
# 4036          Compositae  Angiosperms      Bristly Starbur
# 4554           Rubiaceae  Angiosperms   Coromandel Boxwood
# 4553           Rubiaceae  Angiosperms   Coromandel Boxwood
# 4271      Phyllanthaceae  Angiosperms          Bishop Wood
# 4307      Phyllanthaceae  Angiosperms    Climbing Bridelia
# 4445       Euphorbiaceae  Angiosperms      Climbing Croton
# 4117           Lamiaceae  Angiosperms       Indian Catmint
# 4175          Compositae  Angiosperms                  NaN
# 4236       Lecythidaceae  Angiosperms  Powderpuff Mangrove
# 4708         Leguminosae  Angiosperms      Telegraph Plant
# 4692           Lamiaceae  Angiosperms                  NaN
# 4306      Phyllanthaceae  Angiosperms    Spinous Kino Tree
# 4361           Malvaceae  Angiosperms   East Indian Mallow
# 4483            Rosaceae  Angiosperms               Quince
# 4484            Rosaceae  Angiosperms               Quince
# 4355      Convolvulaceae  Angiosperms        Shankh Pushpi
# 4693           Lamiaceae  Angiosperms           Tubeflower
#
#                                        Med_Synonymous_names  \
# Plant_Id
# 1916                             Althaea rosea, Alcea rosea
# 467                                        Bambusa vulgaris
# 4650                               Cinnamomum glanduliferum
# 4036                                Acanthospermum hispidum
# 4554      Canthium parviflorum, Canthium coromandelicum,...
# 4553      Canthium parviflorum, Canthium coromandelicum,...
# 4271                                     Bischofia javanica
# 4307      Bridelia stipularis, Bridelia scandens, Bridel...
# 4445                                        Croton caudatus
# 4117      Anisomeles ovata, Anisomeles indica, Anisomele...
# 4175                                    Artemisia myriantha
# 4236           Barringtonia racemosa, Barringionia racemosa
# 4708      Desmodium gyrans, Desmodium motorium, Codarioc...
# 4692      Clerodendrum colebrookianum, Clerodendrum glan...
# 4306      Bridelia airy-shawii, Bridelia squamosa, Bride...
# 4361      Corchorus acutangularis, Corchorus acutangulus...
# 4483       Cydonia vulgaris, Cydonia oblonga, Pyrus cydonia
# 4484       Cydonia vulgaris, Cydonia oblonga, Pyrus cydonia
# 4355      Convolvulus pluricaulis, Convolvulus prostratu...
# 4693        Clerodendrum siphonanthus, Clerodendrum indicum
#
#            Med_System_of_medicine Curated
# Plant_Id
# 1916                          NaN       0
# 467                           NaN       0
# 4650                          NaN       1
# 4036                     Ayurveda       1
# 4554             Ayurveda, Siddha       1
# 4553             Ayurveda, Siddha       1
# 4271                       Siddha       1
# 4307                     Ayurveda       1
# 4445                          NaN       1
# 4117                       Siddha       1
# 4175                          NaN       1
# 4236             Ayurveda, Siddha       1
# 4708                          NaN       1
# 4692                          NaN       1
# 4306             Ayurveda, Siddha       1
# 4361              Ayurveda, Unani       1
# 4483      Ayurveda, Siddha, Unani       1
# 4484      Ayurveda, Siddha, Unani       1
# 4355      Ayurveda, Siddha, Unani       1
# 4693             Ayurveda, Siddha       1
#
# [20 rows x 27 columns]
