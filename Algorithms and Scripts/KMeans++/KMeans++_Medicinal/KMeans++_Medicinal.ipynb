# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
# Load in the data and scale it
df = pd.read_csv('final_data_encoded_Med.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['Category_Annuals', 'Category_Aquatic Plants',
#        'Category_Aquatic and Marginal Plants', 'Category_Bamboos',
#        'Category_Bromeliads', 'Category_Bulbous Plants', 'Category_Bulbs',
#        'Category_Cacti & Succulents', 'Category_Climbers',
#        'Category_Climbers and Creepers',
#        ...
#        'Diseases_systemic', 'Diseases_ulcerative', 'Diseases_variant',
#        'Diseases_viral', 'Diseases_visceral', 'Diseases_vulvovaginal',
#        'Diseases_walker', 'Category_Rose_Hybrid_Climbers',
#        'Category_Rose_Miniature_Floribundas', 'Category_Groundcovers_lawns'],
#       dtype='object', length=836)

# %%
df
# Out:
#           Category_Annuals  Category_Aquatic Plants  \
# Plant_Id
# 41                       0                        0
# 42                       0                        0
# 43                       0                        0
# 137                      0                        0
# 143                      0                        0
# ...                    ...                      ...
# 4727                     0                        0
# 4728                     0                        0
# 4729                     0                        0
# 4730                     0                        0
# 4731                     0                        0
#
#           Category_Aquatic and Marginal Plants  Category_Bamboos  \
# Plant_Id
# 41                                           0                 0
# 42                                           0                 0
# 43                                           0                 0
# 137                                          0                 0
# 143                                          0                 0
# ...                                        ...               ...
# 4727                                         0                 0
# 4728                                         0                 0
# 4729                                         0                 0
# 4730                                         0                 0
# 4731                                         0                 0
#
#           Category_Bromeliads  Category_Bulbous Plants  Category_Bulbs  \
# Plant_Id
# 41                          0                        0               0
# 42                          0                        0               0
# 43                          0                        0               0
# 137                         0                        0               0
# 143                         0                        0               0
# ...                       ...                      ...             ...
# 4727                        0                        0               0
# 4728                        0                        0               0
# 4729                        0                        0               0
# 4730                        0                        0               0
# 4731                        0                        0               0
#
#           Category_Cacti & Succulents  Category_Climbers  \
# Plant_Id
# 41                                  0                  0
# 42                                  0                  0
# 43                                  0                  1
# 137                                 0                  0
# 143                                 0                  0
# ...                               ...                ...
# 4727                                0                  0
# 4728                                0                  0
# 4729                                0                  0
# 4730                                0                  0
# 4731                                0                  0
#
#           Category_Climbers and Creepers  ...  Diseases_systemic  \
# Plant_Id                                  ...
# 41                                     0  ...                  0
# 42                                     0  ...                  0
# 43                                     0  ...                  0
# 137                                    0  ...                  0
# 143                                    0  ...                  0
# ...                                  ...  ...                ...
# 4727                                   0  ...                  0
# 4728                                   0  ...                  0
# 4729                                   0  ...                  0
# 4730                                   0  ...                  0
# 4731                                   0  ...                  0
#
#           Diseases_ulcerative  Diseases_variant  Diseases_viral  \
# Plant_Id
# 41                          0                 0               0
# 42                          0                 0               0
# 43                          0                 0               0
# 137                         0                 0               0
# 143                         0                 0               0
# ...                       ...               ...             ...
# 4727                        0                 0               0
# 4728                        0                 0               0
# 4729                        0                 0               0
# 4730                        0                 0               0
# 4731                        0                 0               0
#
#           Diseases_visceral  Diseases_vulvovaginal  Diseases_walker  \
# Plant_Id
# 41                        0                      0                0
# 42                        0                      0                0
# 43                        0                      0                0
# 137                       0                      0                0
# 143                       0                      0                0
# ...                     ...                    ...              ...
# 4727                      0                      0                0
# 4728                      0                      0                0
# 4729                      0                      0                0
# 4730                      0                      0                0
# 4731                      0                      0                0
#
#           Category_Rose_Hybrid_Climbers  Category_Rose_Miniature_Floribundas  \
# Plant_Id
# 41                                    0                                    0
# 42                                    0                                    0
# 43                                    0                                    0
# 137                                   0                                    0
# 143                                   0                                    0
# ...                                 ...                                  ...
# 4727                                  0                                    0
# 4728                                  0                                    0
# 4729                                  0                                    0
# 4730                                  0                                    0
# 4731                                  0                                    0
#
#           Category_Groundcovers_lawns
# Plant_Id
# 41                                  0
# 42                                  1
# 43                                  1
# 137                                 1
# 143                                 0
# ...                               ...
# 4727                                0
# 4728                                0
# 4729                                0
# 4730                                0
# 4731                                0
#
# [958 rows x 836 columns]

# %%
kmean_data = df.copy()
kmean_data
# Out:
#           Category_Annuals  Category_Aquatic Plants  \
# Plant_Id
# 41                       0                        0
# 42                       0                        0
# 43                       0                        0
# 137                      0                        0
# 143                      0                        0
# ...                    ...                      ...
# 4727                     0                        0
# 4728                     0                        0
# 4729                     0                        0
# 4730                     0                        0
# 4731                     0                        0
#
#           Category_Aquatic and Marginal Plants  Category_Bamboos  \
# Plant_Id
# 41                                           0                 0
# 42                                           0                 0
# 43                                           0                 0
# 137                                          0                 0
# 143                                          0                 0
# ...                                        ...               ...
# 4727                                         0                 0
# 4728                                         0                 0
# 4729                                         0                 0
# 4730                                         0                 0
# 4731                                         0                 0
#
#           Category_Bromeliads  Category_Bulbous Plants  Category_Bulbs  \
# Plant_Id
# 41                          0                        0               0
# 42                          0                        0               0
# 43                          0                        0               0
# 137                         0                        0               0
# 143                         0                        0               0
# ...                       ...                      ...             ...
# 4727                        0                        0               0
# 4728                        0                        0               0
# 4729                        0                        0               0
# 4730                        0                        0               0
# 4731                        0                        0               0
#
#           Category_Cacti & Succulents  Category_Climbers  \
# Plant_Id
# 41                                  0                  0
# 42                                  0                  0
# 43                                  0                  1
# 137                                 0                  0
# 143                                 0                  0
# ...                               ...                ...
# 4727                                0                  0
# 4728                                0                  0
# 4729                                0                  0
# 4730                                0                  0
# 4731                                0                  0
#
#           Category_Climbers and Creepers  ...  Diseases_systemic  \
# Plant_Id                                  ...
# 41                                     0  ...                  0
# 42                                     0  ...                  0
# 43                                     0  ...                  0
# 137                                    0  ...                  0
# 143                                    0  ...                  0
# ...                                  ...  ...                ...
# 4727                                   0  ...                  0
# 4728                                   0  ...                  0
# 4729                                   0  ...                  0
# 4730                                   0  ...                  0
# 4731                                   0  ...                  0
#
#           Diseases_ulcerative  Diseases_variant  Diseases_viral  \
# Plant_Id
# 41                          0                 0               0
# 42                          0                 0               0
# 43                          0                 0               0
# 137                         0                 0               0
# 143                         0                 0               0
# ...                       ...               ...             ...
# 4727                        0                 0               0
# 4728                        0                 0               0
# 4729                        0                 0               0
# 4730                        0                 0               0
# 4731                        0                 0               0
#
#           Diseases_visceral  Diseases_vulvovaginal  Diseases_walker  \
# Plant_Id
# 41                        0                      0                0
# 42                        0                      0                0
# 43                        0                      0                0
# 137                       0                      0                0
# 143                       0                      0                0
# ...                     ...                    ...              ...
# 4727                      0                      0                0
# 4728                      0                      0                0
# 4729                      0                      0                0
# 4730                      0                      0                0
# 4731                      0                      0                0
#
#           Category_Rose_Hybrid_Climbers  Category_Rose_Miniature_Floribundas  \
# Plant_Id
# 41                                    0                                    0
# 42                                    0                                    0
# 43                                    0                                    0
# 137                                   0                                    0
# 143                                   0                                    0
# ...                                 ...                                  ...
# 4727                                  0                                    0
# 4728                                  0                                    0
# 4729                                  0                                    0
# 4730                                  0                                    0
# 4731                                  0                                    0
#
#           Category_Groundcovers_lawns
# Plant_Id
# 41                                  0
# 42                                  1
# 43                                  1
# 137                                 1
# 143                                 0
# ...                               ...
# 4727                                0
# 4728                                0
# 4729                                0
# 4730                                0
# 4731                                0
#
# [958 rows x 836 columns]

# %%
# Perform k-means clustering with k-means++ initialization
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
kmeans.fit(kmean_data)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
# Get cluster labels
cluster_labels = kmeans.labels_

# %%
# Add cluster labels to the original data
kmean_data['Cluster'] = cluster_labels

# Display the count of data points in each cluster
print(kmean_data['Cluster'].value_counts())
# Out:
# 3    637
# 0    202
# 1     93
# 2     17
# 4      9
# Name: Cluster, dtype: int64

# %%
# Calculate the count of data points in each cluster
cluster_counts = kmean_data['Cluster'].value_counts()

# Visualize cluster distribution using a pie chart
plt.figure(figsize=(8, 8))
plt.pie(cluster_counts, labels=cluster_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Cluster Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Calculate the silhouette score
silhouette_avg = silhouette_score(kmean_data, cluster_labels)
silhouette_avg
# Out:
# 0.31849254247527997

# %% [markdown]
# ## Hyperparameter Tuning

# %%
new_data=df.copy()

# %%
new_data
# Out:
#           Category_Annuals  Category_Aquatic Plants  \
# Plant_Id
# 41                       0                        0
# 42                       0                        0
# 43                       0                        0
# 137                      0                        0
# 143                      0                        0
# ...                    ...                      ...
# 4727                     0                        0
# 4728                     0                        0
# 4729                     0                        0
# 4730                     0                        0
# 4731                     0                        0
#
#           Category_Aquatic and Marginal Plants  Category_Bamboos  \
# Plant_Id
# 41                                           0                 0
# 42                                           0                 0
# 43                                           0                 0
# 137                                          0                 0
# 143                                          0                 0
# ...                                        ...               ...
# 4727                                         0                 0
# 4728                                         0                 0
# 4729                                         0                 0
# 4730                                         0                 0
# 4731                                         0                 0
#
#           Category_Bromeliads  Category_Bulbous Plants  Category_Bulbs  \
# Plant_Id
# 41                          0                        0               0
# 42                          0                        0               0
# 43                          0                        0               0
# 137                         0                        0               0
# 143                         0                        0               0
# ...                       ...                      ...             ...
# 4727                        0                        0               0
# 4728                        0                        0               0
# 4729                        0                        0               0
# 4730                        0                        0               0
# 4731                        0                        0               0
#
#           Category_Cacti & Succulents  Category_Climbers  \
# Plant_Id
# 41                                  0                  0
# 42                                  0                  0
# 43                                  0                  1
# 137                                 0                  0
# 143                                 0                  0
# ...                               ...                ...
# 4727                                0                  0
# 4728                                0                  0
# 4729                                0                  0
# 4730                                0                  0
# 4731                                0                  0
#
#           Category_Climbers and Creepers  ...  Diseases_systemic  \
# Plant_Id                                  ...
# 41                                     0  ...                  0
# 42                                     0  ...                  0
# 43                                     0  ...                  0
# 137                                    0  ...                  0
# 143                                    0  ...                  0
# ...                                  ...  ...                ...
# 4727                                   0  ...                  0
# 4728                                   0  ...                  0
# 4729                                   0  ...                  0
# 4730                                   0  ...                  0
# 4731                                   0  ...                  0
#
#           Diseases_ulcerative  Diseases_variant  Diseases_viral  \
# Plant_Id
# 41                          0                 0               0
# 42                          0                 0               0
# 43                          0                 0               0
# 137                         0                 0               0
# 143                         0                 0               0
# ...                       ...               ...             ...
# 4727                        0                 0               0
# 4728                        0                 0               0
# 4729                        0                 0               0
# 4730                        0                 0               0
# 4731                        0                 0               0
#
#           Diseases_visceral  Diseases_vulvovaginal  Diseases_walker  \
# Plant_Id
# 41                        0                      0                0
# 42                        0                      0                0
# 43                        0                      0                0
# 137                       0                      0                0
# 143                       0                      0                0
# ...                     ...                    ...              ...
# 4727                      0                      0                0
# 4728                      0                      0                0
# 4729                      0                      0                0
# 4730                      0                      0                0
# 4731                      0                      0                0
#
#           Category_Rose_Hybrid_Climbers  Category_Rose_Miniature_Floribundas  \
# Plant_Id
# 41                                    0                                    0
# 42                                    0                                    0
# 43                                    0                                    0
# 137                                   0                                    0
# 143                                   0                                    0
# ...                                 ...                                  ...
# 4727                                  0                                    0
# 4728                                  0                                    0
# 4729                                  0                                    0
# 4730                                  0                                    0
# 4731                                  0                                    0
#
#           Category_Groundcovers_lawns
# Plant_Id
# 41                                  0
# 42                                  1
# 43                                  1
# 137                                 1
# 143                                 0
# ...                               ...
# 4727                                0
# 4728                                0
# 4729                                0
# 4730                                0
# 4731                                0
#
# [958 rows x 836 columns]

# %%
# Define a range of cluster numbers to try
cluster_range = range(2, 40)  # Adjust the range as needed

# Initialize lists to store silhouette scores
silhouette_scores = []

# Iterate over the range of cluster numbers
for n_clusters in cluster_range:
    # Initialize K-means model
    kmeans = KMeans(n_clusters=n_clusters, init='k-means++', random_state=42)
    
    # Fit K-means model to the data
    kmeans.fit(new_data)
    
    # Get cluster labels for each data point
    cluster_labels = kmeans.labels_
    
    # Calculate silhouette score
    silhouette_avg = silhouette_score(new_data, cluster_labels)
    silhouette_scores.append(silhouette_avg)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
# Iterate over the range of cluster numbers
for n_clusters, score in zip(cluster_range, silhouette_scores):
    print(f"Number of clusters: {n_clusters}, Silhouette score: {score}")
# Out:
# Number of clusters: 2, Silhouette score: 0.4264399719310003
# Number of clusters: 3, Silhouette score: 0.2944145938107554
# Number of clusters: 4, Silhouette score: 0.2700809638879656
# Number of clusters: 5, Silhouette score: 0.2442202710788714
# Number of clusters: 6, Silhouette score: 0.20919657320380153
# Number of clusters: 7, Silhouette score: -0.015038268642348368
# Number of clusters: 8, Silhouette score: 0.23963783615251188
# Number of clusters: 9, Silhouette score: -0.01304590462818175
# Number of clusters: 10, Silhouette score: 0.007422487639719555
# Number of clusters: 11, Silhouette score: 0.013686526931900402
# Number of clusters: 12, Silhouette score: -0.010514879324956393
# Number of clusters: 13, Silhouette score: 0.1291593899529795
# Number of clusters: 14, Silhouette score: -0.006006346722584059
# Number of clusters: 15, Silhouette score: 0.014880726026063945
# Number of clusters: 16, Silhouette score: 0.008591930418938723
# Number of clusters: 17, Silhouette score: 0.014069630520316434
# Number of clusters: 18, Silhouette score: 0.013829613454389435
# Number of clusters: 19, Silhouette score: 0.007138254623087659
# Number of clusters: 20, Silhouette score: -0.007825196746171565
# Number of clusters: 21, Silhouette score: 0.006033774859412433
# Number of clusters: 22, Silhouette score: 0.008021987667672354
# Number of clusters: 23, Silhouette score: 0.008485807443791092
# Number of clusters: 24, Silhouette score: 0.005843375635165973
# Number of clusters: 25, Silhouette score: 0.013473179393936928
# Number of clusters: 26, Silhouette score: 0.004946800115845409
# Number of clusters: 27, Silhouette score: 0.019474914205377072
# Number of clusters: 28, Silhouette score: 0.0011399313824533657
# Number of clusters: 29, Silhouette score: 0.022425136327906648
# Number of clusters: 30, Silhouette score: 0.006946570631158716
# Number of clusters: 31, Silhouette score: 0.01373462541428567
# Number of clusters: 32, Silhouette score: 0.010396856691341634
# Number of clusters: 33, Silhouette score: 0.013704125902114055
# Number of clusters: 34, Silhouette score: 0.020478019418832556
# Number of clusters: 35, Silhouette score: 0.008382795265557321
# Number of clusters: 36, Silhouette score: 0.026191597653624596
# Number of clusters: 37, Silhouette score: 0.02626881240330469
# Number of clusters: 38, Silhouette score: 0.013674170721099714
# Number of clusters: 39, Silhouette score: 0.028862792592421617

# %%
# Plot the silhouette scores for different numbers of clusters
plt.figure(figsize=(12, 8))
plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='-')
plt.title('Silhouette Score vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# %%
# Find the optimal k and corresponding silhouette score
optimal_k = cluster_range[np.argmax(silhouette_scores)]
max_silhouette_score = max(silhouette_scores)
print(f"\nOptimal k: {optimal_k}")
print(f"Corresponding Silhouette Score: {max_silhouette_score}")
# Out:
# Optimal k: 39
# Corresponding Silhouette Score: 0.20974206681668522

# %% [markdown]
# ## Cluster distribution

# %%
cluster_data=df.copy()
cluster_data
# Out:
#           Category_Bamboos  Category_Bromeliads  Category_Cacti & Succulents  \
# Plant_Id
# 1                        0                    0                            1
# 2                        0                    0                            1
# 4                        0                    0                            1
# 5                        0                    0                            1
# 7                        0                    0                            1
# ...                    ...                  ...                          ...
# 2996                     0                    0                            0
# 2997                     0                    0                            0
# 2998                     1                    0                            0
# 2999                     0                    0                            0
# 3000                     0                    0                            0
#
#           Category_Climbers  Category_Creepers & Vines  Category_Ferns  \
# Plant_Id
# 1                         0                          0               0
# 2                         0                          0               0
# 4                         0                          0               0
# 5                         0                          0               0
# 7                         0                          0               0
# ...                     ...                        ...             ...
# 2996                      0                          0               0
# 2997                      0                          0               0
# 2998                      0                          0               0
# 2999                      0                          0               0
# 3000                      0                          0               0
#
#           Category_Flowering Pot Plants  Category_Fruit Plants  \
# Plant_Id
# 1                                     0                      0
# 2                                     0                      0
# 4                                     1                      0
# 5                                     1                      0
# 7                                     1                      0
# ...                                 ...                    ...
# 2996                                  0                      0
# 2997                                  0                      0
# 2998                                  0                      0
# 2999                                  0                      0
# 3000                                  0                      0
#
#           Category_Grasses & Grass like plants  Category_Groundcovers_lawns  \
# Plant_Id
# 1                                            0                            0
# 2                                            0                            0
# 4                                            0                            0
# 5                                            0                            0
# 7                                            0                            0
# ...                                        ...                          ...
# 2996                                         0                            0
# 2997                                         0                            0
# 2998                                         1                            1
# 2999                                         0                            0
# 3000                                         0                            0
#
#           ...  Spread_or_Width_1 to 2 meters  Spread_or_Width_2 to 4 meters  \
# Plant_Id  ...
# 1         ...                              1                              0
# 2         ...                              0                              0
# 4         ...                              0                              0
# 5         ...                              0                              0
# 7         ...                              0                              0
# ...       ...                            ...                            ...
# 2996      ...                              0                              1
# 2997      ...                              0                              1
# 2998      ...                              0                              0
# 2999      ...                              0                              1
# 3000      ...                              0                              0
#
#           Spread_or_Width_4 to 6 meters  Spread_or_Width_6 to 8 meters  \
# Plant_Id
# 1                                     0                              0
# 2                                     0                              0
# 4                                     0                              0
# 5                                     0                              0
# 7                                     0                              0
# ...                                 ...                            ...
# 2996                                  0                              0
# 2997                                  0                              0
# 2998                                  0                              0
# 2999                                  0                              0
# 3000                                  0                              0
#
#           Spread_or_Width_8 to 12 meters  Spread_or_Width_More than 12 meters  \
# Plant_Id
# 1                                      0                                    0
# 2                                      0                                    0
# 4                                      0                                    0
# 5                                      0                                    0
# 7                                      0                                    0
# ...                                  ...                                  ...
# 2996                                   0                                    0
# 2997                                   0                                    0
# 2998                                   0                                    0
# 2999                                   0                                    0
# 3000                                   0                                    0
#
#           Spread_or_Width_less_than_1_meter  Water_Normal  \
# Plant_Id
# 1                                         0             1
# 2                                         1             1
# 4                                         1             1
# 5                                         1             1
# 7                                         1             1
# ...                                     ...           ...
# 2996                                      0             1
# 2997                                      0             1
# 2998                                      1             1
# 2999                                      0             1
# 3000                                      1             1
#
#           Water_Requires_less  Water_Requires_more
# Plant_Id
# 1                           1                    0
# 2                           1                    0
# 4                           1                    0
# 5                           1                    0
# 7                           1                    0
# ...                       ...                  ...
# 2996                        0                    1
# 2997                        0                    1
# 2998                        1                    1
# 2999                        1                    0
# 3000                        0                    0
#
# [2362 rows x 83 columns]

# %%
optimal_data = cluster_data.copy()
optimal_data
# Out:
#           Category_Bamboos  Category_Bromeliads  Category_Cacti & Succulents  \
# Plant_Id
# 1                        0                    0                            1
# 2                        0                    0                            1
# 4                        0                    0                            1
# 5                        0                    0                            1
# 7                        0                    0                            1
# ...                    ...                  ...                          ...
# 2996                     0                    0                            0
# 2997                     0                    0                            0
# 2998                     1                    0                            0
# 2999                     0                    0                            0
# 3000                     0                    0                            0
#
#           Category_Climbers  Category_Creepers & Vines  Category_Ferns  \
# Plant_Id
# 1                         0                          0               0
# 2                         0                          0               0
# 4                         0                          0               0
# 5                         0                          0               0
# 7                         0                          0               0
# ...                     ...                        ...             ...
# 2996                      0                          0               0
# 2997                      0                          0               0
# 2998                      0                          0               0
# 2999                      0                          0               0
# 3000                      0                          0               0
#
#           Category_Flowering Pot Plants  Category_Fruit Plants  \
# Plant_Id
# 1                                     0                      0
# 2                                     0                      0
# 4                                     1                      0
# 5                                     1                      0
# 7                                     1                      0
# ...                                 ...                    ...
# 2996                                  0                      0
# 2997                                  0                      0
# 2998                                  0                      0
# 2999                                  0                      0
# 3000                                  0                      0
#
#           Category_Grasses & Grass like plants  Category_Groundcovers_lawns  \
# Plant_Id
# 1                                            0                            0
# 2                                            0                            0
# 4                                            0                            0
# 5                                            0                            0
# 7                                            0                            0
# ...                                        ...                          ...
# 2996                                         0                            0
# 2997                                         0                            0
# 2998                                         1                            1
# 2999                                         0                            0
# 3000                                         0                            0
#
#           ...  Spread_or_Width_1 to 2 meters  Spread_or_Width_2 to 4 meters  \
# Plant_Id  ...
# 1         ...                              1                              0
# 2         ...                              0                              0
# 4         ...                              0                              0
# 5         ...                              0                              0
# 7         ...                              0                              0
# ...       ...                            ...                            ...
# 2996      ...                              0                              1
# 2997      ...                              0                              1
# 2998      ...                              0                              0
# 2999      ...                              0                              1
# 3000      ...                              0                              0
#
#           Spread_or_Width_4 to 6 meters  Spread_or_Width_6 to 8 meters  \
# Plant_Id
# 1                                     0                              0
# 2                                     0                              0
# 4                                     0                              0
# 5                                     0                              0
# 7                                     0                              0
# ...                                 ...                            ...
# 2996                                  0                              0
# 2997                                  0                              0
# 2998                                  0                              0
# 2999                                  0                              0
# 3000                                  0                              0
#
#           Spread_or_Width_8 to 12 meters  Spread_or_Width_More than 12 meters  \
# Plant_Id
# 1                                      0                                    0
# 2                                      0                                    0
# 4                                      0                                    0
# 5                                      0                                    0
# 7                                      0                                    0
# ...                                  ...                                  ...
# 2996                                   0                                    0
# 2997                                   0                                    0
# 2998                                   0                                    0
# 2999                                   0                                    0
# 3000                                   0                                    0
#
#           Spread_or_Width_less_than_1_meter  Water_Normal  \
# Plant_Id
# 1                                         0             1
# 2                                         1             1
# 4                                         1             1
# 5                                         1             1
# 7                                         1             1
# ...                                     ...           ...
# 2996                                      0             1
# 2997                                      0             1
# 2998                                      1             1
# 2999                                      0             1
# 3000                                      1             1
#
#           Water_Requires_less  Water_Requires_more
# Plant_Id
# 1                           1                    0
# 2                           1                    0
# 4                           1                    0
# 5                           1                    0
# 7                           1                    0
# ...                       ...                  ...
# 2996                        0                    1
# 2997                        0                    1
# 2998                        1                    1
# 2999                        1                    0
# 3000                        0                    0
#
# [2362 rows x 83 columns]

# %%
# Initialize K-means model with a different number of clusters
kmeans = KMeans(n_clusters=39,init='k-means++', random_state=42)  # Adjust the number of clusters as needed

# Fit K-means model to the data
kmeans.fit(cluster_data)

# Get cluster labels for each data point
cluster_labels = kmeans.labels_

# Add cluster labels to the original data
optimal_data['Cluster'] = cluster_labels

# Display the count of data points in each cluster
print(optimal_data['Cluster'].value_counts())

# Calculate the silhouette score
silhouette_avg = silhouette_score(cluster_data, cluster_labels)

print("The average silhouette score is:", silhouette_avg)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 14    172
# 6     148
# 25    108
# 31     99
# 9      95
# 13     84
# 38     80
# 19     71
# 8      71
# 12     70
# 18     65
# 10     64
# 29     63
# 16     62
# 20     62
# 23     61
# 21     60
# 26     59
# 22     59
# 36     56
# 33     55
# 27     55
# 30     51
# 2      48
# 5      48
# 7      45
# 28     45
# 3      44
# 1      41
# 17     39
# 11     39
# 15     38
# 24     36
# 4      33
# 34     33
# 32     32
# 37     24
# 0      24
# 35     23
# Name: Cluster, dtype: int64
# The average silhouette score is: 0.20974206681668522

# %%
# Calculate the count of data points in each cluster
cluster_counts = optimal_data['Cluster'].value_counts()

# Visualize cluster distribution using a pie chart
plt.figure(figsize=(8, 8))
plt.pie(cluster_counts, labels=cluster_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Cluster Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
optimal_data1 = df.copy()
optimal_data1
# Out:
#           Category_Bamboos  Category_Bromeliads  Category_Cacti & Succulents  \
# Plant_Id
# 1                        0                    0                            1
# 2                        0                    0                            1
# 4                        0                    0                            1
# 5                        0                    0                            1
# 7                        0                    0                            1
# ...                    ...                  ...                          ...
# 2996                     0                    0                            0
# 2997                     0                    0                            0
# 2998                     1                    0                            0
# 2999                     0                    0                            0
# 3000                     0                    0                            0
#
#           Category_Climbers  Category_Creepers & Vines  Category_Ferns  \
# Plant_Id
# 1                         0                          0               0
# 2                         0                          0               0
# 4                         0                          0               0
# 5                         0                          0               0
# 7                         0                          0               0
# ...                     ...                        ...             ...
# 2996                      0                          0               0
# 2997                      0                          0               0
# 2998                      0                          0               0
# 2999                      0                          0               0
# 3000                      0                          0               0
#
#           Category_Flowering Pot Plants  Category_Fruit Plants  \
# Plant_Id
# 1                                     0                      0
# 2                                     0                      0
# 4                                     1                      0
# 5                                     1                      0
# 7                                     1                      0
# ...                                 ...                    ...
# 2996                                  0                      0
# 2997                                  0                      0
# 2998                                  0                      0
# 2999                                  0                      0
# 3000                                  0                      0
#
#           Category_Grasses & Grass like plants  Category_Groundcovers_lawns  \
# Plant_Id
# 1                                            0                            0
# 2                                            0                            0
# 4                                            0                            0
# 5                                            0                            0
# 7                                            0                            0
# ...                                        ...                          ...
# 2996                                         0                            0
# 2997                                         0                            0
# 2998                                         1                            1
# 2999                                         0                            0
# 3000                                         0                            0
#
#           ...  Spread_or_Width_1 to 2 meters  Spread_or_Width_2 to 4 meters  \
# Plant_Id  ...
# 1         ...                              1                              0
# 2         ...                              0                              0
# 4         ...                              0                              0
# 5         ...                              0                              0
# 7         ...                              0                              0
# ...       ...                            ...                            ...
# 2996      ...                              0                              1
# 2997      ...                              0                              1
# 2998      ...                              0                              0
# 2999      ...                              0                              1
# 3000      ...                              0                              0
#
#           Spread_or_Width_4 to 6 meters  Spread_or_Width_6 to 8 meters  \
# Plant_Id
# 1                                     0                              0
# 2                                     0                              0
# 4                                     0                              0
# 5                                     0                              0
# 7                                     0                              0
# ...                                 ...                            ...
# 2996                                  0                              0
# 2997                                  0                              0
# 2998                                  0                              0
# 2999                                  0                              0
# 3000                                  0                              0
#
#           Spread_or_Width_8 to 12 meters  Spread_or_Width_More than 12 meters  \
# Plant_Id
# 1                                      0                                    0
# 2                                      0                                    0
# 4                                      0                                    0
# 5                                      0                                    0
# 7                                      0                                    0
# ...                                  ...                                  ...
# 2996                                   0                                    0
# 2997                                   0                                    0
# 2998                                   0                                    0
# 2999                                   0                                    0
# 3000                                   0                                    0
#
#           Spread_or_Width_less_than_1_meter  Water_Normal  \
# Plant_Id
# 1                                         0             1
# 2                                         1             1
# 4                                         1             1
# 5                                         1             1
# 7                                         1             1
# ...                                     ...           ...
# 2996                                      0             1
# 2997                                      0             1
# 2998                                      1             1
# 2999                                      0             1
# 3000                                      1             1
#
#           Water_Requires_less  Water_Requires_more
# Plant_Id
# 1                           1                    0
# 2                           1                    0
# 4                           1                    0
# 5                           1                    0
# 7                           1                    0
# ...                       ...                  ...
# 2996                        0                    1
# 2997                        0                    1
# 2998                        1                    1
# 2999                        1                    0
# 3000                        0                    0
#
# [2362 rows x 83 columns]

# %%
cluster_data1 = df.copy()
cluster_data1
# Out:
#           Category_Bamboos  Category_Bromeliads  Category_Cacti & Succulents  \
# Plant_Id
# 1                        0                    0                            1
# 2                        0                    0                            1
# 4                        0                    0                            1
# 5                        0                    0                            1
# 7                        0                    0                            1
# ...                    ...                  ...                          ...
# 2996                     0                    0                            0
# 2997                     0                    0                            0
# 2998                     1                    0                            0
# 2999                     0                    0                            0
# 3000                     0                    0                            0
#
#           Category_Climbers  Category_Creepers & Vines  Category_Ferns  \
# Plant_Id
# 1                         0                          0               0
# 2                         0                          0               0
# 4                         0                          0               0
# 5                         0                          0               0
# 7                         0                          0               0
# ...                     ...                        ...             ...
# 2996                      0                          0               0
# 2997                      0                          0               0
# 2998                      0                          0               0
# 2999                      0                          0               0
# 3000                      0                          0               0
#
#           Category_Flowering Pot Plants  Category_Fruit Plants  \
# Plant_Id
# 1                                     0                      0
# 2                                     0                      0
# 4                                     1                      0
# 5                                     1                      0
# 7                                     1                      0
# ...                                 ...                    ...
# 2996                                  0                      0
# 2997                                  0                      0
# 2998                                  0                      0
# 2999                                  0                      0
# 3000                                  0                      0
#
#           Category_Grasses & Grass like plants  Category_Groundcovers_lawns  \
# Plant_Id
# 1                                            0                            0
# 2                                            0                            0
# 4                                            0                            0
# 5                                            0                            0
# 7                                            0                            0
# ...                                        ...                          ...
# 2996                                         0                            0
# 2997                                         0                            0
# 2998                                         1                            1
# 2999                                         0                            0
# 3000                                         0                            0
#
#           ...  Spread_or_Width_1 to 2 meters  Spread_or_Width_2 to 4 meters  \
# Plant_Id  ...
# 1         ...                              1                              0
# 2         ...                              0                              0
# 4         ...                              0                              0
# 5         ...                              0                              0
# 7         ...                              0                              0
# ...       ...                            ...                            ...
# 2996      ...                              0                              1
# 2997      ...                              0                              1
# 2998      ...                              0                              0
# 2999      ...                              0                              1
# 3000      ...                              0                              0
#
#           Spread_or_Width_4 to 6 meters  Spread_or_Width_6 to 8 meters  \
# Plant_Id
# 1                                     0                              0
# 2                                     0                              0
# 4                                     0                              0
# 5                                     0                              0
# 7                                     0                              0
# ...                                 ...                            ...
# 2996                                  0                              0
# 2997                                  0                              0
# 2998                                  0                              0
# 2999                                  0                              0
# 3000                                  0                              0
#
#           Spread_or_Width_8 to 12 meters  Spread_or_Width_More than 12 meters  \
# Plant_Id
# 1                                      0                                    0
# 2                                      0                                    0
# 4                                      0                                    0
# 5                                      0                                    0
# 7                                      0                                    0
# ...                                  ...                                  ...
# 2996                                   0                                    0
# 2997                                   0                                    0
# 2998                                   0                                    0
# 2999                                   0                                    0
# 3000                                   0                                    0
#
#           Spread_or_Width_less_than_1_meter  Water_Normal  \
# Plant_Id
# 1                                         0             1
# 2                                         1             1
# 4                                         1             1
# 5                                         1             1
# 7                                         1             1
# ...                                     ...           ...
# 2996                                      0             1
# 2997                                      0             1
# 2998                                      1             1
# 2999                                      0             1
# 3000                                      1             1
#
#           Water_Requires_less  Water_Requires_more
# Plant_Id
# 1                           1                    0
# 2                           1                    0
# 4                           1                    0
# 5                           1                    0
# 7                           1                    0
# ...                       ...                  ...
# 2996                        0                    1
# 2997                        0                    1
# 2998                        1                    1
# 2999                        1                    0
# 3000                        0                    0
#
# [2362 rows x 83 columns]

# %%
# Initialize K-means model with a different number of clusters
kmeans = KMeans(n_clusters=36,init='k-means++', random_state=42)  # Adjust the number of clusters as needed

# Fit K-means model to the data
kmeans.fit(cluster_data1)

# Get cluster labels for each data point
cluster_labels = kmeans.labels_

# Add cluster labels to the original data
optimal_data1['Cluster'] = cluster_labels

# Display the count of data points in each cluster
print(optimal_data['Cluster'].value_counts())

# Calculate the silhouette score
silhouette_avg = silhouette_score(cluster_data1, cluster_labels)

print("The average silhouette score is:", silhouette_avg)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 14    172
# 6     148
# 25    108
# 31     99
# 9      95
# 13     84
# 38     80
# 19     71
# 8      71
# 12     70
# 18     65
# 10     64
# 29     63
# 16     62
# 20     62
# 23     61
# 21     60
# 26     59
# 22     59
# 36     56
# 33     55
# 27     55
# 30     51
# 2      48
# 5      48
# 7      45
# 28     45
# 3      44
# 1      41
# 17     39
# 11     39
# 15     38
# 24     36
# 4      33
# 34     33
# 32     32
# 37     24
# 0      24
# 35     23
# Name: Cluster, dtype: int64
# The average silhouette score is: 0.2095814612591566

# %%
# Calculate the count of data points in each cluster
cluster_counts = optimal_data1['Cluster'].value_counts()

# Visualize cluster distribution using a pie chart
plt.figure(figsize=(8, 8))
plt.pie(cluster_counts, labels=cluster_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Cluster Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
